# %% [markdown]
# <a href="https://colab.research.google.com/github/ObjectTechnologySolutionsIndia-OTSI/LLM-Trail/blob/Rajeshwari/Text_to_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install OpenAI
# !pip install --upgrade openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.4/225.4 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# ...

# %%
#To integrate OpenAI features into your project, include the following imports: import openai for accessing OpenAI functionality and import os for configuring the API key.
import openai
import os
#To access the value of the 'OPENAI_API_KEY' environment variable using the os module.
os.environ['OPENAI_API_KEY'] = "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"

# %%
#Generate spoken audio from input text
from pathlib import Path
from openai import OpenAI
client = OpenAI()

speech_file_path = Path("samplespeech2.mp3")
response = client.audio.speech.create(
  model="tts-1",
  voice="alloy",
  input="Hi everyone. This is Rajeshwari. Iam here to give presentation on contribution of openai in artificial intelligence"
)

response.stream_to_file(speech_file_path)

# %%
###Generate spoken from the prompt given in Hindi lanuage
from IPython.display import Audio
from openai import OpenAI

client = OpenAI()

response = client.audio.speech.create(
    model="tts-1",
    voice="alloy",
    input="नमस्ते, यह एक परीक्षण है",
)
output_file_path = "output.mp3"
response.stream_to_file("output.mp3")
# Play the generated audio directly in the notebook
Audio(output_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
###One way of converting the mp3 file to text is by using transcriptions api
from openai import OpenAI
client = OpenAI()

audio_file= open("/content/output.mp3", "rb")
transcript = client.audio.transcriptions.create(
  model="whisper-1",
  language="en",
  file=audio_file,
)
transcript.text
# Out:
# 'Namaste, yeh ek parikshan hai.'

# %%
###Code for converting the mp3 file to text. For this first we have to set the runtime as GPU instead of CPU
# install openai's whisper
# !pip install git+https://github.com/openai/whisper.git

# update the packages
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-0jhvp3_1
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-0jhvp3_1
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 12.5 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=802825 sha256=7c6804adef6c548e421dcbf1b731d97b9e3a76a47a0dc52ef94834f902f9919b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ko2tk_rh/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...

# %%
##Code to translate mp3 audio file to text
# Run Whisper AI:
# !whisper /content/samplespeech2.mp3 --model medium.en

# Additional arguments:
# !whisper -h
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:26<00:00, 58.3MiB/s]
# [00:00.000 --> 00:02.460]  Hi everyone, this is Rajeshwari.
# [00:02.460 --> 00:06.760]  I am here to give presentation on contribution of open eye in artificial intelligence.
# usage: whisper [-h] [--model MODEL] [--model_dir MODEL_DIR] [--device DEVICE]
#                [--output_dir OUTPUT_DIR] [--output_format {txt,vtt,srt,tsv,json,all}]
#                [--verbose VERBOSE] [--task {transcribe,translate}]
# ...

# %%
##Code to translate mp3 audio file from any language to English
from openai import OpenAI
client = OpenAI()

audio_file= open("/content/output.mp3", "rb")
transcript = client.audio.translations.create(
  model="whisper-1",
  file=audio_file
)
transcript
# Out:
# Translation(text='Namaste, this was a test.')

# %%
#Code to translate mp3 audio file from any language to English using whisper directly
# ------- change dir ----------------------------------------- specify language
# !whisper /content/output.mp3 --model medium --language English --task translate

# Additional arguments:
# !whisper -h
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:16<00:00, 93.8MiB/s]
# [00:00.000 --> 00:01.600]  Namaste, this is an experiment.
# usage: whisper [-h] [--model MODEL] [--model_dir MODEL_DIR] [--device DEVICE]
#                [--output_dir OUTPUT_DIR] [--output_format {txt,vtt,srt,tsv,json,all}]
#                [--verbose VERBOSE] [--task {transcribe,translate}]
# ...

# %%
#Moderation
client = OpenAI()

client.moderations.create(input="I want to kill them.")
# Out:
# ModerationCreateResponse(id='modr-8dGO63GbfRFpEYT82nx3IB86CHxPU', model='text-moderation-006', results=[Moderation(categories=Categories(harassment=True, harassment_threatening=True, hate=False, hate_threatening=False, self_harm=False, self_harm_instructions=False, self_harm_intent=False, sexual=False, sexual_minors=False, violence=True, violence_graphic=False, self-harm=False, sexual/minors=False, hate/threatening=False, violence/graphic=False, self-harm/intent=False, self-harm/instructions=False, harassment/threatening=True), category_scores=CategoryScores(harassment=0.4741021394729614, harassment_threatening=0.3966355323791504, hate=0.338640958070755, hate_threatening=0.029252545908093452, self_harm=1.0363953029113304e-09, self_harm_instructions=6.100447295757927e-13, self_harm_intent=1.7282976438881548e-10, sexual=1.726894652165356e-06, sexual_minors=3.477892391856585e-07, violence=0.9924718141555786, violence_graphic=1.502044426615612e-07, self-harm=1.0363953029113304e-09, sexua
# ...
