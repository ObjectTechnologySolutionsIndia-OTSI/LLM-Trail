# %% [markdown]
# <a href="https://colab.research.google.com/github/ObjectTechnologySolutionsIndia-OTSI/LLM-Trail/blob/Rajeshwari/Data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install OpenAI
# !pip install --upgrade openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.4/225.4 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# ...

# %%
##Install pandasai
# !pip install pandasai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 68.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 66.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.2/808.2 kB 52.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 80.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 0.9.2
#     Uninstalling duckdb-0.9.2:
#       Successfully uninstalled duckdb-0.9.2
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.23
#     Uninstalling SQLAlchemy-2.0.23:
#       Successfully uninstalled SQLAlchemy-2.0.23
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pandasai import SmartDataframe
import pandas as pd

# %%
# Replace "your_data.csv" with the actual path to your CSV file
csv_file_path = "/content/drive/MyDrive/Colab Notebooks/dcs_data_formatted 1.csv"

# Read data from the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the DataFrame
print(df)
# Out:
#         State Code     State Name  District Code District Name  \
# 0                9  UTTAR PRADESH            148     GORAKHPUR
# 1                9  UTTAR PRADESH            148     GORAKHPUR
# 2                9  UTTAR PRADESH            148     GORAKHPUR
# 3                9  UTTAR PRADESH            148     GORAKHPUR
# 4                9  UTTAR PRADESH            148     GORAKHPUR
# ...            ...            ...            ...           ...
# 116447           9  UTTAR PRADESH            140       AYODHYA
# 116448           9  UTTAR PRADESH            140       AYODHYA
# 116449           9  UTTAR PRADESH            140       AYODHYA
# 116450           9  UTTAR PRADESH            140       AYODHYA
# 116451           9  UTTAR PRADESH            140       AYODHYA
#
#         Sub-District Code Sub-District Name  Village Code     Village Name  \
# 0                     950         GORAKHPUR        185585     RAMPUR KHURD
# ...

# %%
from pandasai.llm import OpenAI

llm = OpenAI(api_token="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")

# %%
sdf = SmartDataframe(df, config={"llm": llm})

# %%
##Prompt to give descriptive statistics
sdf.chat("Give the descriptive statistics")
# Out:
#           State Code  District Code  Sub-District Code  Village Code  \
# count  116452.000000  116452.000000      116452.000000  1.164520e+05
# mean       10.637421     509.300218        1744.133351  2.120014e+05
# std         4.547734   17819.042941       17846.461340  2.040217e+05
# min         9.000000     118.000000         701.000000  1.089970e+05
# 25%         9.000000     140.000000         864.000000  1.527020e+05
# 50%         9.000000     152.000000         939.000000  1.801310e+05
# 75%         9.000000     179.000000         995.000000  2.084420e+05
# max        27.000000  999999.000000      999999.000000  9.999999e+06
#
#           crop_code      sown_area
# count  1.164520e+05  116452.000000
# mean   4.025100e+05      45.661859
# std    3.780606e+05     186.292832
# min    4.800000e+01       0.000000
# 25%    1.017010e+05       0.584000
# 50%    2.014000e+05       2.696000
# 75%    7.005000e+05      17.130000
# max    1.504300e+06   17920.933000

# %%
##Prompt in an more detailed way gives the more detailed descritive statistics
sdf.chat("Performing descriptive statistics on each column to summarize main characteristics of the dataset.")
# Out:
#            State Code     State Name  District Code District Name  \
# count   116452.000000         116452  116452.000000        116452
# unique            NaN              7            NaN            88
# top               NaN  UTTAR PRADESH            NaN        HARDOI
# freq              NaN         102993            NaN         10379
# mean        10.637421            NaN     509.300218           NaN
# std          4.547734            NaN   17819.042941           NaN
# min          9.000000            NaN     118.000000           NaN
# 25%          9.000000            NaN     140.000000           NaN
# 50%          9.000000            NaN     152.000000           NaN
# 75%          9.000000            NaN     179.000000           NaN
# max         27.000000            NaN  999999.000000           NaN
#
#         Sub-District Code Sub-District Name  Village Code Village Name  \
# count       116452.000000            116452  1.164520e+05       116452
# ...

# %%
###Cleaning up data
sdf.chat("Lets cleanup the state column by removing whie spaces in between")
# Out:
#         State Code    State Name  District Code District Name  \
# 0                9  UTTARPRADESH            148     GORAKHPUR
# 1                9  UTTARPRADESH            148     GORAKHPUR
# 2                9  UTTARPRADESH            148     GORAKHPUR
# 3                9  UTTARPRADESH            148     GORAKHPUR
# 4                9  UTTARPRADESH            148     GORAKHPUR
# ...            ...           ...            ...           ...
# 116447           9  UTTARPRADESH            140       AYODHYA
# 116448           9  UTTARPRADESH            140       AYODHYA
# 116449           9  UTTARPRADESH            140       AYODHYA
# 116450           9  UTTARPRADESH            140       AYODHYA
# 116451           9  UTTARPRADESH            140       AYODHYA
#
#         Sub-District Code Sub-District Name  Village Code     Village Name  \
# 0                     950         GORAKHPUR        185585     RAMPUR KHURD
# ...

# %%
##Quering regarding data
sdf.chat("Top 5 crops in the state Uttar pradesh")
# Out:
#      crop_name     sown_area
# 173       Rice  3.206987e+06
# 191  Sugarcane  5.527196e+05
# 186    Sorghum  1.174172e+05
# 86   Groundnut  1.010135e+05
# 125      Maize  8.694427e+04

# %%
##Detailed query on data
sdf.chat("Least 5 villages for the crop rice. Do the comparion with area column. Give only villagenames,district names,state names and area sown")
# Out:
#       Village Name District Name State Name Area Sown
# 84037   KESARAJPUR       NUAPADA     ODISHA      0.00
# 77058   DUMERPADAR       NUAPADA     ODISHA      0.00
# 25276    KHURDGUMA       NUAPADA     ODISHA      0.00
# 47269     SALEKELA       NUAPADA     ODISHA      0.00
# 54730     AMBAGUDA       NUAPADA     ODISHA      0.00

# %%
##Query to create a simple bar chart
sdf.chat("Plot a bar chart of the top 5 crops by state")
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
##Creating a simple pie chart
sdf.chat("Plot a piechart for top 5 states by area and for the crop maize and the legend should be provided on right side of the chart. Legend should be present outsode of the chart. Please add the name of the chart as States by Rice crop")
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
##Creating a simple regression model with information on what variables needs to be added and what needs to be deleted from the model and provide specific metics after building the required model
sdf.chat("Lets build a regression model considering area as deependent variable and rest all as independent variables. Please exclude crop_code from the model. After building the model please provide the mean square error, r2 value and adjusted r2 value")
# Out:
# 'Mean Squared Error: 32716.98742933429\nR-squared: 0.07539116923051559\nAdjusted R-squared: 0.06483086513131153'
